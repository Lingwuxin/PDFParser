# %%
import pdfplumber

pdf=pdfplumber.open('test.PDF')
page=pdf.pages[6]
table=page.find_tables()[0]
bbox=table.bbox
bbox
# Out:
# (90.14400000000002, 125.29999999999995, 531.4983899999995, 292.009995)

# %%
im=page.to_image()
words=page.extract_words()
bbox=(277.49, 43.98899999999992, 343.01, 53.969999999999914)
im.draw_rect(bbox)

# %%
page.rects
# Out:
# [{'x0': 88.464,
#   'y0': 785.76,
#   'x1': 532.054,
#   'y1': 786.48,
#   'width': 443.59,
#   'height': 0.7200000000000273,
#   'pts': [(88.464, 785.76),
#    (532.054, 785.76),
#    (532.054, 786.48),
#    (88.464, 786.48)],
#   'linewidth': 0,
#   'stroke': False,
#   'fill': True,
#   'evenodd': True,
#   'stroking_color': None,
#   'non_stroking_color': 0,
#   'object_type': 'rect',
#   'page_number': 7,
#   'top': 55.43999999999994,
#   'bottom': 56.15999999999997,
#   'doctop': 5106.959999999999},
#  {'x0': 89.904,
#   'y0': 716.38,
#   'x1': 90.384,
#   'y1': 716.86,
#   'width': 0.480000000000004,
#   'height': 0.4800000000000182,
#   'pts': [(89.904, 716.38),
#    (90.384, 716.38),
#    (90.384, 716.86),
#    (89.904, 716.86)],
#   'linewidth': 0,
#   'stroke': False,
#   'fill': True,
#   'evenodd': True,
#   'stroking_color': None,
#   'non_stroking_color': 0,
#   'object_type': 'rect',
#   'page_number': 7,
#   'top': 125.05999999999995,
# ...

# %%
num=9
a=11
b=10
if not num<a or not num<b:
    print('test')
