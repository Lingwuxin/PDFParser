# %%
import pdfplumber

pdf=pdfplumber.open('8180733.PDF')
page=pdf.pages[6]
table=page.find_tables()[0]
bbox=table.bbox
bbox
# Out:
# (90.14400000000002, 125.29999999999995, 531.4983899999995, 292.009995)

# %%
im=page.to_image()
im.draw_rect(bbox)

# %%
page.chars
# Out:
# dict_keys(['char', 'rect'])
